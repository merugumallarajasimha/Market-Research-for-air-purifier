# %%
import pandas as pd

# %%
vehicle=pd.read_csv("C:\\Users\\merug\\Desktop\\Market Fit Research for Air Purifier\\Dataful_Datasets\\master-data-state-vehicle-class-and-fuel-type-wise-total-number-of-vehicles-registered-in-each-month-in-india.csv")

# %%
vehicle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199552 entries, 0 to 199551
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   year           199552 non-null  int64
#  1   month          199552 non-null  object
#  2   state          199552 non-null  object
#  3   rto            199552 non-null  object
#  4   vehicle_class  199552 non-null  object
#  5   fuel           199552 non-null  object
#  6   value          199552 non-null  int64
#  7   unit           199552 non-null  object
#  8   note           0 non-null       float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 13.7+ MB

# %%
vehicle=vehicle.drop(columns=['unit'])
vehicle=vehicle.drop(columns=['note'])

# %%
vehicle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199552 entries, 0 to 199551
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   year           199552 non-null  int64
#  1   month          199552 non-null  object
#  2   state          199552 non-null  object
#  3   rto            199552 non-null  object
#  4   vehicle_class  199552 non-null  object
#  5   fuel           199552 non-null  object
#  6   value          199552 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 10.7+ MB

# %%
vehicle.isnull().sum()
# Out:
# year             0
# month            0
# state            0
# rto              0
# vehicle_class    0
# fuel             0
# value            0
# dtype: int64

# %%
vehicle['year'].unique()
# Out:
# array([2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015,
#        2014])

# %%
vehicle['month'].unique()
# Out:
# array(['April', 'February', 'January', 'December', 'November', 'October',
#        'September', 'August', 'July', 'June', 'May', 'March'],
#       dtype=object)

# %%
vehicle['state'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %%
vehicle['rto'].unique()
# Out:
# array(['All Vahan Running Office'], dtype=object)

# %%
vehicle['vehicle_class'].value_counts()
# Out:
# vehicle_class
# MOTOR CAR                         23934
# THREE WHEELER (PASSENGER)         15049
# MOTOR CAB                         14957
# GOODS CARRIER                     13216
# M-CYCLE/SCOOTER                   12688
#                                   ...
# STANDARD CORPORATION INDIA LTD        1
# TIL LIMITED                           1
# VASHAN AGRICULTURE WORKS LTD          1
# VOLKSWAGEN INDIA PVT LTD              1
# VOLVO INDIA PVT LTD                   1
# Name: count, Length: 197, dtype: int64

# %%
vehicle['fuel'].value_counts()
# Out:
# fuel
# DIESEL                81962
# PETROL                44295
# ELECTRIC(BOV)         17410
# PETROL/CNG            13040
# NOT APPLICABLE        11493
# CNG ONLY               9514
# PETROL/LPG             6112
# PETROL/HYBRID          5248
# DIESEL/HYBRID          3155
# PURE EV                2022
# LPG ONLY               1805
# PETROL/ETHANOL         1697
# STRONG HYBRID EV        866
# SOLAR                   326
# ETHANOL                 142
# Not Available           119
# LNG                      85
# BS IV                    46
# PLUG-IN HYBRID EV        39
# DUAL DIESEL/CNG          33
# BS III                   32
# EURO 3                   15
# B(T)S III A              12
# EURO 4                   11
# BS III/IV                11
# B(T)S IV                 10
# BS II                     9
# BS I                      6
# FUEL CELL HYDROGEN        6
# METHANOL                  6
# EURO 2                    5
# B(T)S III                 5
# DUAL DIESEL/LNG           4
# ...

# %%
vehicle.head()
# Out:
#    year  month                        state                       rto  \
# 0  2025  April  Andaman and Nicobar Islands  All Vahan Running Office
# 1  2025  April  Andaman and Nicobar Islands  All Vahan Running Office
# 2  2025  April  Andaman and Nicobar Islands  All Vahan Running Office
# 3  2025  April  Andaman and Nicobar Islands  All Vahan Running Office
# 4  2025  April  Andaman and Nicobar Islands  All Vahan Running Office
#
#      vehicle_class           fuel  value
# 0              BUS         DIESEL      2
# 1    GOODS CARRIER         DIESEL     23
# 2    GOODS CARRIER         PETROL      1
# 3  M-CYCLE/SCOOTER  ELECTRIC(BOV)      1
# 4  M-CYCLE/SCOOTER         PETROL    387

# %%
#vehicle.to_csv("vehicle_clean.csv",index=False)

# %%
vehicle['state'].value_counts().count()
# Out:
# np.int64(35)

# %%
vehicle['state'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)
